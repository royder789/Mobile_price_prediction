# %%
import pandas as pd
import numpy as np
from sklearn.feature_selection import chi2
from sklearn.feature_selection import SelectKBest

# %%
data=pd.read_csv('train.csv')
x=data.iloc[:,0:20]
y=data.iloc[:,-1]
#apply select k best to 10
best_feature=SelectKBest(score_func=chi2,k=10)
fit=best_feature.fit(x,y)
fit.scores_
dfscores=pd.DataFrame(fit.scores_)
dfcolumns=pd.DataFrame(x.columns)
featuresScores=pd.concat([dfcolumns,dfscores],axis=1)
featuresScores.columns=['fea','sco']
ten_features=featuresScores.sort_values(by= 'sco',ascending=False).head(10)['fea'].values

# %% [markdown]
# FEATURE IMPORTANCE

# %%
from sklearn.ensemble import RandomForestCLassifier
import matplotlib.pyplot as plt
model=RandomForestClassifier()
model.fit(x,y)
model.feature_importances_
featureImportance=pd.DataFrame(model.feature_importances_,index=x.columns,columns=['Importnace'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9448\2634852259.py in <module>
# ----> 1 from sklearn.ensemble import RandomForestCLassifier
#       2 import matplotlib.pyplot as plt
#       3 model=RandomForestClassifier()
#       4 model.fit(x,y)
#
# ImportError: cannot import name 'RandomForestCLassifier' from 'sklearn.ensemble' (D:\anacondaa3\envs\py3-TF2.0\lib\site-packages\sklearn\ensemble\__init__.py)

# %%
#correlation

import seaborn
import matplotlib.pyplot as plt
data_corr=data.corr()
data_corr
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data_corr)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9448\1464803346.py in <module>
#       1 plt.figure(figsize=(20,20))
# ----> 2 sns.heatmap(data_corr)
#       3 plt.show()
#
# NameError: name 'sns' is not defined

# %%
# Out:
# array(['ram', 'px_height', 'battery_power', 'px_width', 'mobile_wt',
#        'int_memory', 'sc_w', 'talk_time', 'fc', 'sc_h'], dtype=object)
